# %% [markdown]
# 给定一个二叉树，检查它是否是镜像对称的。
#
#
#
# 例如，二叉树 [1,2,2,3,4,4,3] 是对称的。
#
#     1
#    / \
#   2   2
#  / \ / \
# 3  4 4  3
#
#
# 但是下面这个 [1,2,2,null,3,null,3] 则不是镜像对称的:
#
#     1
#    / \
#   2   2
#    \   \
#    3    3
#
#
# 进阶：
#
# 你可以运用递归和迭代两种方法解决这个问题吗？
#
# 来源：力扣（LeetCode）
# 链接：https://leetcode-cn.com/problems/symmetric-tree
# 著作权归领扣网络所有。商业转载请联系官方授权，非商业转载请注明出处。

# %%
# Definition for a binary tree node.
'''
    1
   / \
  2   2
 / \ / \
3  4 4  3
'''
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def isSymmetric(self, root: TreeNode) -> bool:
        if not root.left and not root.right: # 左右都空  else 左右都不空 或 有一个为空一个不空
            return True 
        elif not root.left or not root.right: # 左右有一个空 一个不空 else 左右都不空
            return False
        def dfs1(node:TreeNode,l):
            if not node:
                l.append('#')
                return
            dfs1(node.left,l)
            dfs1(node.right,l)
            l.append(node.val)
        def dfs2(node:TreeNode,l):
            if not node:
                l.append('#')
                return
            dfs2(node.right,l)
            dfs2(node.left,l)
            l.append(node.val)
        res1 = []
        res2 = []
        dfs1(root.left,res1)
        dfs2(root.right,res2)
        return res1==res2

# %%
# Definition for a binary tree node.
'''
    1
   / \
  2   2
 / \ / \
3  4 4  3
'''


class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:
    def isSymmetric(self, root: TreeNode) -> bool:
        if not root: return True

        def dfs(node_l: TreeNode, node_r: TreeNode) -> bool:
            if node_l and not node_r:
                return False
            elif node_r and not node_l:
                return False
            elif not node_l and not node_r:
                return True
            elif node_l.val != node_r.val:
                return False
            # 不为空 且相等
            outside = dfs(node_l.left, node_r.right)
            inside = dfs(node_l.right, node_r.left)
            return outside and inside

        return dfs(root.left, root.right)
