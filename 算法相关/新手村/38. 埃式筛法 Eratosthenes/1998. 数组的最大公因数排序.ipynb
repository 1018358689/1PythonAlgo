# %%
N = 10**5
lpf = list(range(N + 1))  # 最小质因数
for x in range(2, int(N**.5) + 1):
    if lpf[x] == x:
        for y in range(x * x, N + 1, x):
            lpf[y] = x


class Solution:

    def gcdSort(self, nums: List[int]) -> bool:
        n = len(nums)
        roots = list(range(n))

        def find(x):
            if roots[x] != x:
                roots[x] = find(roots[x])
            return roots[x]

        def union(x, y):
            rx, ry = find(x), find(y)
            if rx != ry:
                roots[rx] = ry

        lst = sorted(set(nums))
        adj = defaultdict(set)
        for i, x in enumerate(lst):
            while x > 1:
                p = lpf[x]
                adj[p].add(i)
                x //= p
        for vals in adj.values():
            for x, y in pairwise(vals):
                union(x, y)
        for x, y in zip(nums, sorted(nums)):
            if x != y and find(bisect_left(lst, x)) != find(bisect_left(lst, y)):
                return False
        return True

# %%
N = 10**5
lpf = list(range(N + 1))  # 最小质因数
for x in range(2, int(N**.5) + 1):
    if lpf[x] == x:
        for y in range(x * x, N + 1, x):
            lpf[y] = x


class Solution:

    def gcdSort(self, nums: List[int]) -> bool:
        roots = defaultdict(int)

        def find(x):
            if roots[x] != x:
                roots[x] = find(roots[x])
            return roots[x]

        def union(x, y):
            if roots[x] == 0: roots[x] = x
            if roots[y] == 0: roots[y] = y
            rx, ry = find(x), find(y)
            if rx != ry:
                roots[rx] = ry

        adj = defaultdict(set)
        for x in set(nums):
            ori = x
            while x > 1:
                p = lpf[x]
                adj[p].add(ori)
                x //= p
        for vals in adj.values():
            for x, y in pairwise(vals):
                union(x, y)
        for x, y in zip(nums, sorted(nums)):
            if x != y and find(x) != find(y):
                return False
        return True
