# %%
class Node:

    def __init__(self, key, val) -> None:
        self.key = key
        self.val = val
        self.pre = None
        self.next = None


class DoubleList:

    def __init__(self) -> None:
        self.head = Node(-1, -1)
        self.end = Node(-1, -1)
        self.head.next = self.end
        self.end.pre = self.head

    def addAfter(self, newNode: Node, preNode: Node):
        nxtNode = preNode.next
        newNode.next = nxtNode
        newNode.pre = preNode
        preNode.next = newNode
        nxtNode.pre = newNode

    def delNode(self, node: Node):
        preNode, nxtNode = node.pre, node.next
        preNode.next = nxtNode
        nxtNode.pre = preNode

    def move2last(self, node: Node):
        if node.next == self.end:
            return
        self.delNode(node)
        self.addAfter(node, self.end.pre)


class LRUCache:

    def __init__(self, capacity: int):
        self.cap = capacity
        self.dl = DoubleList()
        self.key2node = {}

    def get(self, key: int) -> int:
        if key not in self.key2node:
            return -1
        node = self.key2node[key]
        self.dl.move2last(node)
        return node.val

    def put(self, key: int, value: int) -> None:
        # 原来不存在则插入
        if key not in self.key2node:
            newNode = Node(key, value)
            if not self.cap:  # 满容量则删除头结点
                self.key2node.pop(self.dl.head.next.key)
                self.dl.delNode(self.dl.head.next)
            else:  # 未满则添加新结点
                self.cap -= 1
            self.dl.addAfter(newNode, self.dl.end.pre)
            self.key2node[key] = newNode
        # 原来已存在则更改
        else:
            node = self.key2node[key]
            node.val = value
            self.dl.move2last(node)


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %%
class Node:

    def __init__(self, key, val) -> None:
        self.key = key
        self.val = val
        self.pre = None
        self.next = None


class DoubleList:

    def __init__(self) -> None:
        self.head = Node(-1, -1)
        self.end = Node(-1, -1)
        self.head.next = self.end
        self.end.pre = self.head

    def addAfter(self, newNode: Node, preNode: Node):
        nxtNode = preNode.next
        newNode.next = nxtNode
        newNode.pre = preNode
        preNode.next = newNode
        nxtNode.pre = newNode

    def delNode(self, node: Node):
        preNode, nxtNode = node.pre, node.next
        preNode.next = nxtNode
        nxtNode.pre = preNode

    def move2last(self, node: Node):
        if node.next == self.end:
            return
        self.delNode(node)
        self.addAfter(node, self.end.pre)


class LRUCache:

    def __init__(self, capacity: int):
        self.cap = capacity
        self.dl = DoubleList()
        self.key2node = {}

    def get(self, key: int) -> int:
        if key not in self.key2node:
            return -1
        node = self.key2node[key]
        self.dl.move2last(node)
        return node.val

    def put(self, key: int, value: int) -> None:
        # 原来不存在则插入
        if key not in self.key2node:
            newNode = Node(key, value)
            if len(self.key2node) == self.cap:  # 满容量则删除头结点 添加新节点
                self.key2node.pop(self.dl.head.next.key)
                self.dl.delNode(self.dl.head.next)
            self.dl.addAfter(newNode, self.dl.end.pre)
            self.key2node[key] = newNode
        # 原来已存在则更改
        else:
            node = self.key2node[key]
            node.val = value
            self.dl.move2last(node)


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)
