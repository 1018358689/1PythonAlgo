# %%
from collections import deque
from typing import Optional


# Definition for a binary tree node.
class TreeNode:

    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def cnt(nums: list):  # 排序所需最少交换次数
            ha = {n: i for i, n in enumerate(sorted(nums))}
            counts = len(nums)
            roots = list(range(counts))
            rank = [1] * counts

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    if rank[rx] < rank[ry]:
                        roots[rx] = ry
                    elif rank[ry] < rank[rx]:
                        roots[ry] = rx
                    else:
                        roots[rx] = ry
                        rank[ry] += 1
                    nonlocal counts
                    counts -= 1

            for n in nums:
                union(ha[n], ha[nums[ha[n]]])
            return len(nums) - counts

        q = deque([root])
        ans = 0
        while q:
            nums = []
            for _ in range(len(q)):
                cur = q.popleft()
                nums.append(cur.val)
                if cur.left: q.append(cur.left)
                if cur.right: q.append(cur.right)
            ans += cnt(nums)
        return ans

# %%
from collections import deque
from typing import Optional


# Definition for a binary tree node.
class TreeNode:

    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def cnt(nums: list):  # 排序所需最少交换次数
            ha = {n: i for i, n in enumerate(sorted(nums))}
            nums = [ha[n] for n in nums] # 离散化
            counts = len(nums)
            roots = list(range(counts))
            rank = [1] * counts

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    if rank[rx] < rank[ry]:
                        roots[rx] = ry
                    elif rank[ry] < rank[rx]:
                        roots[ry] = rx
                    else:
                        roots[rx] = ry
                        rank[ry] += 1
                    nonlocal counts
                    counts -= 1

            for n in nums:
                union(n, nums[n])
            return len(nums) - counts

        q = deque([root])
        ans = 0
        while q:
            nums = []
            for _ in range(len(q)):
                cur = q.popleft()
                nums.append(cur.val)
                if cur.left: q.append(cur.left)
                if cur.right: q.append(cur.right)
            ans += cnt(nums)
        return ans

# %%
from collections import deque
from bisect import bisect_left
from typing import Optional


# Definition for a binary tree node.
class TreeNode:

    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def cnt(nums: list):  # 排序所需最少交换次数
            b = sorted(nums)
            nums = [bisect_left(b, n) for n in nums]  # 离散化
            counts = len(nums)
            roots = list(range(counts))
            rank = [1] * counts

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    if rank[rx] < rank[ry]:
                        roots[rx] = ry
                    elif rank[ry] < rank[rx]:
                        roots[ry] = rx
                    else:
                        roots[rx] = ry
                        rank[ry] += 1
                    nonlocal counts
                    counts -= 1

            for n in nums:
                union(n, nums[n])
            return len(nums) - counts  # 置换环 为总长度-环个数

        q = deque([root])
        ans = 0
        while q:
            nums = []
            for _ in range(len(q)):
                cur = q.popleft()
                nums.append(cur.val)
                if cur.left: q.append(cur.left)
                if cur.right: q.append(cur.right)
            ans += cnt(nums)
        return ans

# %%
from bisect import bisect_left


def cnt(nums: list):  # 排序所需最少交换次数
    b = sorted(nums)
    nums = [bisect_left(b, n) for n in nums]  # 离散化
    counts = len(nums)
    roots = list(range(counts))
    rank = [1] * counts

    def find(x):
        if roots[x] != x:
            roots[x] = find(roots[x])
        return roots[x]

    def union(x, y):
        rx, ry = find(x), find(y)
        if rx != ry:
            if rank[rx] < rank[ry]:
                roots[rx] = ry
            elif rank[ry] < rank[rx]:
                roots[ry] = rx
            else:
                roots[rx] = ry
                rank[ry] += 1
            nonlocal counts
            counts -= 1

    for n in nums:
        union(n, nums[n])
    return len(nums) - counts


cnt([4, 3, 2, 1])
# Out:
# 2
