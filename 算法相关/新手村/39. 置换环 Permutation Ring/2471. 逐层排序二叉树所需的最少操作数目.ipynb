# %% [markdown]
# ![](2023-06-02-15-36-17.png)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def pr(arr):  # 置换环算法 求 使递增的最少交换次数
            n = len(arr)
            arr = sorted(range(n), key=lambda x: arr[x])
            vis = [0] * n
            cnt = 0
            for x in arr:
                if vis[x]: continue
                while not vis[x]:
                    vis[x] = 1
                    x = arr[x]
                cnt += 1
            return n - cnt

        q = deque([root])
        ans = 0
        while q:
            arr = []
            for _ in range(len(q)):
                x = q.popleft()
                arr.append(x.val)
                for y in x.left, x.right:
                    if y: q.append(y)
            ans += pr(arr)
        return ans

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def pr(arr):  # 置换环算法 求 使递增的最少交换次数
            n = len(arr)
            roots = list(range(n))
            count = n

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    roots[rx] = ry
                    nonlocal count
                    count -= 1
                    return True  # 成功合并
                return False  # 本身就联通

            arr = sorted(range(n), key=lambda x: arr[x])
            vis = [0] * n
            for x in arr:
                if vis[x]: continue
                while not vis[x]:
                    vis[x] = 1
                    union(x, arr[x])
                    x = arr[x]
            return n - count

        q = deque([root])
        ans = 0
        while q:
            arr = []
            for _ in range(len(q)):
                x = q.popleft()
                arr.append(x.val)
                for y in x.left, x.right:
                    if y: q.append(y)
            ans += pr(arr)
        return ans

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def pr(arr):  # 置换环算法 求 使递增的最少交换次数
            n = len(arr)
            roots = list(range(n))
            count = n

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    roots[rx] = ry
                    nonlocal count
                    count -= 1

            lst = sorted(arr)
            for i, x in enumerate(arr):
                idx = bisect_left(lst, x)
                union(idx, i)
            return n - count

        q = deque([root])
        ans = 0
        while q:
            arr = []
            for _ in range(len(q)):
                x = q.popleft()
                arr.append(x.val)
                for y in x.left, x.right:
                    if y: q.append(y)
            ans += pr(arr)
        return ans

# %%
# 不用deque 但要注意 要求是 从左往右递增序列的置换环 因此要tmp[::-1]

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def pr(arr):  # 置换环算法 求 使递增的最少交换次数
            n = len(arr)
            roots = list(range(n))
            count = n

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    roots[rx] = ry
                    nonlocal count
                    count -= 1

            lst = sorted(arr)
            for i, x in enumerate(arr):
                idx = bisect_left(lst, x)
                union(idx, i)
            return n - count

        q = [root]
        ans = 0
        while q:
            arr = []
            tmp = []
            for _ in range(len(q)):
                x = q.pop()
                for y in x.left, x.right:
                    if y:
                        tmp.append(y)
                        arr.append(y.val)
            ans += pr(arr)
            q = tmp[::-1]
        return ans

# %%
# 不用deque 且避免tmp顺序问题 更加优雅

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    def minimumOperations(self, root: Optional[TreeNode]) -> int:

        def pr(arr):  # 置换环算法 求 使递增的最少交换次数
            n = len(arr)
            roots = list(range(n))
            count = n

            def find(x):
                if roots[x] != x:
                    roots[x] = find(roots[x])
                return roots[x]

            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    roots[rx] = ry
                    nonlocal count
                    count -= 1

            lst = sorted(arr)
            for i, x in enumerate(arr):
                idx = bisect_left(lst, x)
                union(idx, i)
            return n - count

        q = [root]
        ans = 0
        while q:
            arr = []
            tmp = []
            for x in q:
                for y in x.left, x.right:
                    if y:
                        tmp.append(y)
                        arr.append(y.val)
            ans += pr(arr)
            q = tmp
        return ans
