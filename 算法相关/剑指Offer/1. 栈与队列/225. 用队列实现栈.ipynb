# %%
from collections import deque


class MyStack:

    def __init__(self):
        self.q1 = deque([])
        self.q2 = deque([])

    def push(self, x: int) -> None:
        self.q1.append(x)

    def pop(self) -> int:
        while len(self.q1) != 1:
            self.q2.append(self.q1.popleft())
        tmp = self.q1.popleft()
        self.q1, self.q2 = self.q2, self.q1
        return tmp

    def top(self) -> int:
        while len(self.q1) != 1:
            self.q2.append(self.q1.popleft())
        self.q2.append(tmp := self.q1.popleft())
        self.q1, self.q2 = self.q2, self.q1
        return tmp

    def empty(self) -> bool:
        return not self.q1


# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %%
from collections import deque


class MyStack:

    def __init__(self):
        self.q1 = deque([])
        self.q2 = deque([])

    def push(self, x: int) -> None:
        if not self.q1:
            self.q1.append(x)
        else:
            self.q2.append(x)

    def pop(self) -> int:
        if not self.q2:
            while len(self.q1) != 1:
                self.q2.append(self.q1.popleft())
            tmp = self.q1.popleft()
        else:
            while len(self.q2) != 1:
                self.q1.append(self.q2.popleft())
            tmp = self.q2.popleft()
        return tmp

    def top(self) -> int:
        if not self.q2:
            while len(self.q1) != 1:
                self.q2.append(self.q1.popleft())
            self.q2.append(tmp := self.q1.popleft())
        else:
            while len(self.q2) != 1:
                self.q1.append(self.q2.popleft())
            self.q1.append(tmp := self.q2.popleft())
        return tmp

    def empty(self) -> bool:
        return not self.q1 and not self.q2


# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %%
from collections import deque


class MyStack:

    def __init__(self):
        self.q1 = deque([])
        self.q2 = deque([])

    def push(self, x: int) -> None:
        self.q2.append(x)
        while self.q1:
            self.q2.append(self.q1.popleft())
        self.q1, self.q2 = self.q2, self.q1

    def pop(self) -> int:
        return self.q1.popleft()

    def top(self) -> int:
        return self.q1[0]

    def empty(self) -> bool:
        return not self.q1


# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()
