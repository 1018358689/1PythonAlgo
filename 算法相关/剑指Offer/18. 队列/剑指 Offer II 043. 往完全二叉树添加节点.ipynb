# %%
# Definition for a binary tree node.
class TreeNode:

    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


from collections import deque


class CBTInserter:

    def __init__(self, root: TreeNode):
        self.l = [] # 广度优先遍历 存节点
        self.root = root
        q = deque([root])
        while q:
            tmp = []
            for _ in range(len(q)):
                cur = q.popleft()
                tmp.append(cur)
                if cur.left: q.append(cur.left)
                if cur.right: q.append(cur.right)
            self.l += tmp

    def insert(self, v: int) -> int:
        idx = len(self.l)
        node = TreeNode(v)
        self.l.append(node)
        pIdx = idx - 1 >> 1 # 父节点索引
        parent = self.l[pIdx]
        if idx & 1 == 1: # 索引奇数则是左孩子 偶数右孩子
            parent.left = node
        else:
            parent.right = node
        return parent.val

    def get_root(self) -> TreeNode:
        return self.root


# Your CBTInserter object will be instantiated and called as such:
# obj = CBTInserter(root)
# param_1 = obj.insert(v)
# param_2 = obj.get_root()

# %%
# Definition for a binary tree node.
class TreeNode:

    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


from collections import deque


class CBTInserter:

    def __init__(self, root: TreeNode):
        self.l = deque([])  # 广度优先遍历 存有空孩子的节点
        self.root = root
        q = deque([root])
        while q:
            cur = q.popleft()
            if not cur.left or not cur.right:
                self.l.append(cur)
            if cur.left: q.append(cur.left)
            if cur.right: q.append(cur.right)

    def insert(self, v: int) -> int:
        self.l.append(TreeNode(v))
        if self.l[0].left is None:
            self.l[0].left = self.l[-1]
            return self.l[0].val
        else:
            self.l[0].right = self.l[-1]
            return self.l.popleft().val

    def get_root(self) -> TreeNode:
        return self.root


# Your CBTInserter object will be instantiated and called as such:
# obj = CBTInserter(root)
# param_1 = obj.insert(v)
# param_2 = obj.get_root()
